# %%
from surprise import Reader, Dataset, SVD
from surprise.model_selection import train_test_split
import pandas as pd

ratings = pd.read_csv('ratings_small.csv')

reader = Reader(rating_scale=(0.5, 5))
data = Dataset.load_from_df(ratings[['userId','movieId','rating']], reader)

trainset, testset = train_test_split(data, test_size=0.2)

algo = SVD()
algo.fit(trainset)

predictions = algo.test(testset)
print("Training complete!")
# Out:
# Training complete!

# %%
from surprise.model_selection import cross_validate
results = cross_validate(algo, data, measures=['RMSE','MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9021  0.8998  0.8953  0.8960  0.8905  0.8967  0.0040
# MAE (testset)     0.6943  0.6958  0.6903  0.6885  0.6856  0.6909  0.0037
# Fit time          1.45    2.00    2.38    2.36    2.35    2.11    0.36
# Test time         0.23    0.36    0.33    0.37    0.34    0.32    0.05

# %%
svd = SVD()
cross_validate(svd, data, measures=['RMSE', 'MAE'])
# Out:
# {'test_rmse': array([0.89109236, 0.89989171, 0.90368349, 0.88434898, 0.89879028]),
#  'test_mae': array([0.68618606, 0.69012218, 0.69761828, 0.68278243, 0.69170762]),
#  'fit_time': (1.707498550415039,
#   1.4558944702148438,
#   2.3610641956329346,
#   2.154965400695801,
#   2.2252590656280518),
#  'test_time': (0.20438241958618164,
#   0.34478211402893066,
#   0.33104658126831055,
#   0.22754597663879395,
#   0.3538525104522705)}

# %%
trainset=data.build_full_trainset()
svd.fit(trainset)

# %%
ratings[ratings['userId']==1]
# Out:
#     userId  movieId  rating   timestamp
# 0        1       31     2.5  1260759144
# 1        1     1029     3.0  1260759179
# 2        1     1061     3.0  1260759182
# 3        1     1129     2.0  1260759185
# 4        1     1172     4.0  1260759205
# 5        1     1263     2.0  1260759151
# 6        1     1287     2.0  1260759187
# 7        1     1293     2.0  1260759148
# 8        1     1339     3.5  1260759125
# 9        1     1343     2.0  1260759131
# 10       1     1371     2.5  1260759135
# 11       1     1405     1.0  1260759203
# 12       1     1953     4.0  1260759191
# 13       1     2105     4.0  1260759139
# 14       1     2150     3.0  1260759194
# 15       1     2193     2.0  1260759198
# 16       1     2294     2.0  1260759108
# 17       1     2455     2.5  1260759113
# 18       1     2968     1.0  1260759200
# 19       1     3671     3.0  1260759117

# %%
svd.predict(1,302,3)
# Out:
# Prediction(uid=1, iid=302, r_ui=3, est=2.6982230428694414, details={'was_impossible': False})
